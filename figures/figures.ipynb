# %%
import pandas as pd

try:
    df = pd.read_csv('/content/Data from Moodle devs after preprocessing(Sheet1).csv')
    print(df.head()) # Print the first few rows to verify
except FileNotFoundError:
    print("Error: File not found. Please ensure the file exists at the specified path.")
except pd.errors.ParserError:
    print("Error: Could not parse the CSV file. Please check the file format.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
#    Credibility  Clarity  Completeness  Consistency  Empathy  Familiarity  \
# 0          3.0      3.5           2.0            3      2.5            4
# 1          4.0      4.0           3.5            5      3.5            3
# 2          4.0      3.5           3.0            4      3.5            4
# 3          5.0      5.0           5.0            5      5.0            4
# 4          4.0      3.5           3.5            4      4.0            5
#
#    Friendliness  Attraction  Liking  Similarity  \
# 0             3           3     3.0         2.5
# 1             5           4     3.5         3.5
# 2             4           3     4.0         3.5
# 3             5           4     5.0         4.5
# 4             4           3     3.5         4.0
#
#    Usefulness and Willingness to use
# 0                           3.333333
# 1                           2.666667
# 2                           3.333333
# 3                           4.333333
# 4                           3.000000

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['figure.dpi'] = 300  # Set DPI for all figures

boxprops = dict(linewidth=1.2, color='black')
medianprops = dict(linewidth=2, color='black')
whiskerprops = dict(linewidth=1.2, color='black')
capprops = dict(linewidth=1.2, color='black')

df.plot(kind='box', vert=False, figsize=(10, 6),
        boxprops=boxprops, medianprops=medianprops,
        whiskerprops=whiskerprops, capprops=capprops)
plt.xlim(0.9, 5.1)
plt.show()

# %%
try:
    df2 = pd.read_csv('/content/Data from students(Sheet1).csv')
    print(df2.head()) # Print the first few rows to verify
except FileNotFoundError:
    print("Error: File not found. Please ensure the file exists at the specified path.")
except pd.errors.ParserError:
    print("Error: Could not parse the CSV file. Please check the file format.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
#    Credibility  Clarity  Completeness  Consistency  Empathy  Familiarity  \
# 0          4.0      4.0           4.0            4      3.5            4
# 1          3.5      3.0           4.5            4      4.5            3
# 2          3.5      3.0           4.5            4      4.5            3
# 3          4.0      4.5           4.5            4      3.5            5
# 4          4.0      3.5           2.5            5      3.5            2
#
#    Friendliness  Attraction  Liking  Similarity  \
# 0             3           2     3.0         3.0
# 1             3           3     2.5         3.0
# 2             3           3     2.5         3.0
# 3             4           4     3.5         3.5
# 4             3           3     3.0         3.5
#
#    Usefulness and Willingness to Use
# 0                           3.333333
# 1                           2.333333
# 2                           2.333333
# 3                           4.333333
# 4                           4.000000

# %%
df2.plot(kind='box', vert=False, figsize=(10, 6),
        boxprops=boxprops, medianprops=medianprops,
        whiskerprops=whiskerprops, capprops=capprops)
plt.xlim(0.9, 5.1)
plt.show()
